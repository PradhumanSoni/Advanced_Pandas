# %% [markdown]
# **(I) Cleaning the Data**

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df_filled=df
median_year_salary= df['salary_year_avg'].median()
median_hour_salary= df['salary_hour_avg'].median()

# %%
df_filled.fillna({'salary_year_avg':median_year_salary,
                  'salary_hour_avg':median_hour_salary}, inplace=True)

# %%
df_unique= df_filled

# %%
df_unique = df_unique.drop_duplicates()

# %%
df_unique
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %% [markdown]
# **(II) Management**

# %%
df_unique.sample(frac=0.1)
# Out:
#               job_title_short  \
# 507907          Data Engineer
# 202872          Data Engineer
# 333020         Data Scientist
# 509060         Data Scientist
# 706766  Senior Data Scientist
# ...                       ...
# 204808   Senior Data Engineer
# 130497          Data Engineer
# 739146           Data Analyst
# 410016           Data Analyst
# 525962   Senior Data Engineer
#
#                                                 job_title      job_location  \
# 507907                            Principal Data Engineer       Belfast, UK
# 202872               Data Engineering Consultant (Hybrid)   Minneapolis, MN
# 333020                                     Data Scientist         Singapore
# 509060  Informatiker (m/w/d) Data Science / Softwareen...  Cologne, Germany
# 706766                              Senior Data Scientist    Manchester, UK
# ...                                                   ...               ...
# ...
